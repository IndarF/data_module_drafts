# %% [raw]
# # ASSIGNMENT CONFIG
# init_cell: true
# export_cell: true
# files:
#     - desserts.csv
#     - Sugar_bomb.csv
# export_cell:
#     pdf: false
#     force_save: false
# solutions_pdf: true
# template_pdf: false
# generate:
#     points_possible: 26
#     show_stdout: true
#     zips: false

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# # Module A HW 1 Draft
# Version: August 20th, 2025
#
# This homework assignment focuses on 3 aspects of coding:
#
# 1. Primitive Data Types
# 2. Variables
# 3. Built-in Functions

# %% [markdown]
# <hr style="border: 1px solid #fdb515;" />
#
# ## Part A: Variables
#
# To get familiar with variables, we are going to create a profile that contains information about you through storing information through variables.

# %% [raw]
# # BEGIN QUESTION
# name: q1
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>Question 1:</b> Let's make our profile by assigning values to variables! For refreshers, you can look back on our lecture content.
# </div>

# %%
# Fill out the ... part with your information.
# If you do not fill comfortable sharing your profile, you can make up a profile.

name = ...
age = ...
city = ...
state = ...

# These variables are checking whether you are a student/have a job right now, what data type would work best?
student = ...
job = ...

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q2
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>Question 2:</b> Use the print() built-in function to output the values assigned to the variables.
# </div>
#
# <details>
#     <summary>Sample Output: </summary>
#     <img src="https://github.com/IndarF/data_module_drafts/blob/main/Fundamentals/Homeworks/Homework%201/Q2_edited.png?raw=true" width="800"/>
# </details>

# %%
#Type your answer here

# %% [raw]
# # END QUESTION

# %% [markdown]
# <hr style="border: 1px solid #fdb515;" />
#
# ## Part B: Data Type

# %% [markdown]
# Now let's try to understand data types of these variables. For each question, assign your answer from the multiple choice in a string format.
#
#         Example) What is a cat?
#         1.   A feline species
#         2.   A human
#         3.   An alien
#
#         answer = "1"

# %% [markdown]
# <div class="alert alert-info">
# <b>Question 3:</b> What is the data type of `name`?
#
#   1.   Integers
#   2.   Floats
#   3.   Strings
#   4.   Booleans
#   5.   None
# </div>

# %% [raw]
# # BEGIN QUESTION
# name: q3
# points: 2

# %% [raw]
# # BEGIN SOLUTION

# %%
answer_3 = "3" # SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(answer_3) == type("word")
# Out:
# True

# %%
answer_3 == "3"
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q4
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>Question 4:</b> What is the data type of `age`?
#
#   1.   Integers
#   2.   Floats
#   3.   Strings
#   4.   Booleans
#   5.   None
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
answer_4 = "1" # SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(answer_4) == type("word")
# Out:
# True

# %%
answer_4 == "1"
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q5
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>Question 5:</b> List all the variables that are strings:
#
# <ul>
#     <li>name</li>
#     <li>age</li>
#     <li>city</li>
#     <li>state</li>
#     <li>student</li>
#     <li>job</li>
# </ul>

# %% [markdown]
# *Type your answer here*

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q6
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>Question 6:</b> Where do you see yourself in 5 years? Let's create a profile of your future self.
#
# To do this, fill in where you see yourself in 5 years into the new variables listed below.
# </div>

# %%
five_year_later_local = ...
five_year_later_job = ...

# %% [markdown]
# <div class="alert alert-info">
# Next, use the print() built-in function to output the values assigned to the variables.
# </div>
# <details>
#     <summary>Sample Output: </summary>
#     <img src="https://github.com/IndarF/data_module_drafts/blob/main/Fundamentals/Homeworks/Homework%201/Q6_edited.png?raw=true" width="800"/>
# </details>

# %%
#Type your answer here

# %% [raw]
# # END QUESTION

# %% [markdown]
# <hr style="border: 1px solid #fdb515;" />
#
# ## Part C: Arithmetic Operators

# %% [raw]
# # BEGIN QUESTION
# name: q7
# points: 2

# %% [markdown]
# In python, we can use arithmetic operators to increase the value for age, meaning it isn't necessary to create a new variable!
#
# Make sure to use the previous variables from Question 1 in your updated profile print statement.
#
# <div class="alert alert-info">
# <b>Question 7:</b> Repeat question 6 but include your age after 5 years in the updated portion of your printed statement.
# </div>
#
# <details>
#     <summary>Sample Output: </summary>
#     <img src="https://github.com/IndarF/data_module_drafts/blob/main/Fundamentals/Homeworks/Homework%201/Q7_edited.png?raw=true" width="800"/>
# </details>

# %%
#Type your answer here

# %% [raw]
# # END QUESTION

# %% [markdown]
# <hr style="border: 1px solid #fdb515;" />
#
# ## Part D: Lists and Sorting
#
# An integral part of python programming is utilizing **lists** to store information, whether it be numerical or categorical.

# %% [raw]
# # BEGIN QUESTION
# name: q8
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>Question 8:</b> You are having a garage sale, and you need to keep track of the <b>clothes</b> you have that need to be sold.
#
# Create a list named <b>clothes</b>, which has the following items: <i>shirts, pants, shorts, jackets, and hats</i>

# %% [raw]
# # BEGIN SOLUTION

# %%
clothes = ["shirts", "pants", "shorts", "jackets", "hats"] # SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(clothes, list)
# Out:
# True

# %%
len(clothes) == 5
# Out:
# True

# %%
# HIDDEN
clothes == ["shirts", "pants", "shorts", "jackets", "hats"]
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q9
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>Question 9:</b> Now, create anohter list called <b>inventory</b> which keeps track of just the number of each clothing item you have: 7 shirts, 4 pants, 2 shorts, 5 jackets, and 3 hats.

# %% [raw]
# # BEGIN SOLUTION

# %%
inventory = [7, 4, 2, 5, 3] # SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(inventory, list)
# Out:
# True

# %%
len(inventory) == 5
# Out:
# True

# %%
# HIDDEN
inventory == [7, 4, 2, 5, 3]
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q10
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>Question 10:</b> How many total items of clothing are you selling?
#
# <i>Hint: Use the sum() function!</i>
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
total = sum(inventory) # SOLUTION
print(total)
# Out:
# 21

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(total, int)
# Out:
# True

# %%
total == 21
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q11
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>Question 11:</b> Output the sorted inventory list using a built-in function.
#
# (Sort the inventory list by name alphabetically)
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
sorted_list = sorted(clothes) # SOLUTION
print(sorted_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sorted_list = sorted(clothes) # SOLUTION
#       2 print(sorted_list)
#
# NameError: name 'clothes' is not defined

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(sorted_list, list)
# Out:
# True

# %%
len(sorted_list) == 5
# Out:
# True

# %%
sorted_list == ['hats', 'jackets', 'pants', 'shirts', 'shorts']
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q12
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>Question 12:</b> Find the Mean for the Frozen Desserts Data Set
#
# Output the Mean for the Grams of Sugar Column Only using Arithmetic operators (+,-,*,/)
#
# Properly format the print() function to label the answer
# </div>
#
# <img src="https://github.com/IndarF/data_module_drafts/blob/main/Fundamentals/Homeworks/Homework%201/frozen_desserts.jpg?raw=true" style="width:50%"/>

# %% [raw]
# # BEGIN SOLUTION

# %%
dessert_mean = 20.2 # SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(dessert_mean) == float
# Out:
# True

# %%
dessert_mean - 20.2 < 0.0001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q13
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>Question 12:</b> Find the Mean for the Sugar Bomb Data Set
#
# Output the Mean for the Grams of Sugar Column Only using Arithmetic operators (+,-,*,/)
#
# Properly format the print() function to label the answer
# </div>
#
# <img src="https://github.com/IndarF/data_module_drafts/blob/main/Fundamentals/Homeworks/Homework%201/sugar_bomb.png?raw=true" style="width:50%" />

# %% [raw]
# # BEGIN SOLUTION

# %%
sbomb_mean = 22.77 # SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(sbomb_mean) == float
# Out:
# True

# %%
sbomb_mean - 22.77 < 0.0001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION
