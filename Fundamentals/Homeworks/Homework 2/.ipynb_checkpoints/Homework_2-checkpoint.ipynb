# %% [raw]
# # ASSIGNMENT CONFIG
# init_cell: true
# export_cell: true
# export_cell:
#     pdf: false
#     force_save: false
# solutions_pdf: true
# template_pdf: false
# generate:
#     points_possible: 28
#     show_stdout: true
#     zips: false

# %%
# Don't change this cell; just run it. 

import numpy as np
from datascience import *
#import d8error

# %% [markdown]
# # Homework 2: Built-in Functions and Numpy
#
# The main topics covered in Homework 2 are:
# <ul>
#     <li> Debugging</li>
#     <li> Built-In Functions</li>
#     <li> Objects, Lists </li>
#     <li>Numpy </li>
# </ul>
#
# ---

# %% [markdown]
# ## Part 1: Debugging

# %% [markdown]
# <div class="alert alert-info">
# <b> 1. Debug the incorrect code below.
#
# Output the mean average only using arithmetic operators [+, -, *, /]
# </b>
# </div>
#
# ```python
# # expected output:
# # mean average = 218.33333...
# sample = [25  35, 100, 900, 200, “50”
# print(25 + 35, + 100, + 900 / 7)
# ```

# %%
# Type answer here

# %% [markdown]
# ---
# ## Part 2: Built-In Functions and Numpy
#
# For this next part of the homework, we will be using Numpy and python's built-in functions to analyze real-world data sets.
#
# We will be looking at <b>Individual Hospital Statistics for California.</b> These are non-federal, short-term, acute care hospitals in California. The dataset can be accessed directly using the following link or by the website:
# * [California Hospital Dataset](https://docs.google.com/spreadsheets/d/1d10ZoDGTBr6CMJDfZQZRByyo9aDP55ASw22Jg-3ZpVo/edit?gid=0#gid=0)
# * [California Hospital Website](https://www.ahd.com/states/hospital_CA.html)
#
# The two cities we will be focusing on are <b>San Francisco</b> and <b>Los Angeles</b>.
#
# <b>San Francisco Hospitals (13):</b>
# <ul>
#     <li>Chinese Hospital</li>
#     <li>CPMC Davies Campus</li>
#     <li>CPMC Mission Bernal Campus & Orthopedic Institute</li>
#     <li>CPMC Van Ness Campus</li>
#     <li>Kaiser Permanente San Francisco Medical Center</li>
#     <li>Laguna Honda Hospital and Rehabilitation Center</li>
#     <li>San Francisco VA Medical Center</li>
#     <li>UCSF Betty Irene Moore Women's Hospital</li>
#     <li>UCSF Health Hyde Hospital</li>
#     <li>UCSF Health Stanyan Hospital</li>
#     <li>UCSF Helen Diller Medical Center at Parnassus Heights</li>
#     <li>UCSF Mission Bay Campus</li>
#     <li>Zuckerberg San Francisco General Hospital and Trauma Center</li>
# </ul>
#
# <b>Los Angeles Hospitals (18):</b>
# <ul>
#     <li>Adventist Health White Memorial</li>
#     <li>California Hospital Medical Center</li>
#     <li>Cedars-Sinai Medical Center</li>
#     <li>CHA Hollywood Presbyterian Medical Center</li>
#     <li>Docs Surgical Hospital</li>
#     <li>East Los Angeles Doctors Hospital</li>
#     <li>LA Downtown Medical Center Downtown Campus</li>
#     <li>Los Angeles Community Hospital</li>
#     <li>Los Angeles General Medical Center</li>
#     <li>Los Angeles Medical Center</li>
#     <li>Martin Luther King, Jr. Community Hospital</li>
#     <li>PIH Health Good Samaritan Hospital</li>
#     <li>Ronald Reagan UCLA Medical Center</li>
#     <li>The Keck Hospital of USC</li>
#     <li>UCLA Mattel Children's Hospital</li>
#     <li>USC Norris Comprehensive Cancer Center</li>
#     <li>West Los Angeles Medical Center</li>
#     <li>West Los Angeles VA Medical Center</li>
# </ul>

# %% [markdown]
# ---
# ## Sum Methods
#
# The following questions focus on the summation methods in Python.

# %%
staffed_beds_SF
# Out:
# [81, 209, 120, 274, 239, 780, 0, 0, 226, 158, 887, 0, 397]

# %%
staffed_beds_LA
# Out:
# [390,
#  318,
#  913,
#  434,
#  17,
#  127,
#  315,
#  212,
#  603,
#  560,
#  152,
#  331,
#  446,
#  323,
#  0,
#  60,
#  265,
#  0]

# %% [raw]
# # BEGIN QUESTION
# name: q2
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>2. Use the sum() built-in function to calculate total staffed beds for San Francisco Hospitals.
#
# Utilize a Python list to hold the number of staffed beds for each hospital. </b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_sum_SF = sum(staffed_beds_SF) # SOLUTION
bed_sum_SF
# Out:
# 3371

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_sum_SF) == int
# Out:
# True

# %%
bed_sum_SF - 3371 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q3
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>3. Use the sum() built-in function to calculate total staffed beds for Los Angeles Hospitals.
#
# Utilize a Python list to hold the number of staffed beds for each hospital. </b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_sum_LA = sum(staffed_beds_LA) # SOLUTION
bed_sum_LA
# Out:
# 5466

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_sum_LA) == int
# Out:
# True

# %%
bed_sum_LA - 5466 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q4
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>4. Use the <i>Numpy</i> built-in function to calculate total staffed beds for San Francisco Hospitals.
#
# Utilize a Python list to hold the number of staffed beds for each hospital. </b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_npsum_SF = np.sum(staffed_beds_SF) # SOLUTION
bed_npsum_SF
# Out:
# 3371

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_npsum_SF) == np.int64
# Out:
# True

# %%
bed_npsum_SF - 3371 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q5
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>5. Use the <i>Numpy</i> built-in function to calculate total staffed beds for Los Angeles Hospitals.
#
# Utilize a Python list to hold the number of staffed beds for each hospital. </b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_npsum_LA = np.sum(staffed_beds_LA) # SOLUTION
bed_npsum_LA
# Out:
# 5466

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_npsum_LA) == np.int64
# Out:
# True

# %%
bed_npsum_LA - 5466 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ---
# ## Mean Methods
#
# The following questions focus  on mean methods in Python.

# %% [raw]
# # BEGIN QUESTION
# name: q6
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>6. Use the sum() built-in function to calculate the mean for total staffed beds for San Francisco Hospitals.
#
# Utilize a Python list to hold the number of staffed beds for each hospital. </b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_mean_SF = sum(staffed_beds_SF) / 13 # SOLUTION
bed_mean_SF
# Out:
# 259.3076923076923

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_mean_SF) == float
# Out:
# True

# %%
bed_mean_SF - 3371/13 < 0.0001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q7
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>7. Use the sum() built-in function to calculate the mean for total staffed beds for Los Angeles Hospitals.
#
# Utilize a Python list to hold the number of staffed beds for each hospital. </b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_mean_LA = sum(staffed_beds_LA) / 18 # SOLUTION
bed_mean_LA
# Out:
# 303.6666666666667

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_mean_LA) == float
# Out:
# True

# %%
bed_mean_LA - 5466 / 18 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q8
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>8. Use Numpy to calculate the mean for total staffed beds for San Francisco Hospitals.
#
# Utilize a Python list to hold the number of staffed beds for each hospital. </b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_mean_SF = np.mean(staffed_beds_SF) # SOLUTION
bed_mean_SF
# Out:
# 259.30769230769232

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_mean_SF) == np.float64
# Out:
# True

# %%
bed_mean_SF - 3371/13 < 0.0001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q9
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>9. Use Numpy to calculate the mean for total staffed beds for Los Angeles Hospitals.
#
# Utilize a Python list to hold the number of staffed beds for each hospital. </b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_mean_LA = np.mean(staffed_beds_LA) # SOLUTION
bed_mean_LA
# Out:
# 303.66666666666669

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_mean_LA) == np.float64
# Out:
# True

# %%
bed_mean_LA - 5466 / 18 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ---
# ## Standard Deviation Methods
#
# The following questions focus on Standard Deviation in python.

# %% [raw]
# # BEGIN QUESTION
# name: q10
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>10. Use Numpy to calculate the standard deviation for total staffed beds for Los Angeles Hospitals.
#
# Utilize a Python list to hold the number of staffed beds for each hospital.</b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_sd_LA = np.std(staffed_beds_LA) # SOLUTION
bed_sd_LA
# Out:
# 231.28121410957701

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_sd_LA) == np.float64
# Out:
# True

# %%
bed_sd_LA - 231.2812141 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q11
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>11. Use Numpy to calculate the standard deviation for total staffed beds for San Francisco Hospitals.
#
# Utilize a Python list to hold the number of staffed beds for each hospital.</b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_sd_SF = np.std(staffed_beds_SF) # SOLUTION
bed_sd_SF
# Out:
# 270.54514328705477

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_sd_SF) == np.float64
# Out:
# True

# %%
bed_sd_LA - 270.5451433 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ---
# ## Median Methods
#
# The following questions focus on median methods in python.

# %% [raw]
# # BEGIN QUESTION
# name: q12
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>12. Use the sorted() built-in function to identify the median amount for total staffed beds for San Francisco Hospitals.
#
# (Utilize a Python list to hold the number of staffed beds for each hospital.)
#
# *Keep in mind the process for finding the median for an odd vs even data set*
# </b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_median_SF = 209 # SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_median_SF) ==  int
# Out:
# True

# %%
bed_median_SF - 209 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q13
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>13. Use the sorted() built-in function to identify the median amount for total staffed beds for Los Angeles Hospitals.
#
# (Utilize a Python list to hold the number of staffed beds for each hospital.)
#
# *Keep in mind the process for finding the median for an odd vs even data set*
# </b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_median_LA = (315 + 318) / 2 # SOLUTION
bed_median_LA
# Out:
# 316.5

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_median_LA) ==  float
# Out:
# True

# %%
bed_median_LA - 316.5 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q14
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>14. Use Numpy to identify the median to identify the median amount for total staffed beds for San Francisco Hospitals.
#
# (Utilize a Python list to hold the number of staffed beds for each hospital.)
#
# </b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_median_SF = np.median(staffed_beds_SF) # SOLUTION
bed_median_SF
# Out:
# 209.0

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_median_SF) ==  np.float64
# Out:
# True

# %%
bed_median_SF - 209 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q15
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>15. Use Numpy to identify the median to identify the median amount for total staffed beds for Los Angeles Hospitals.
#
# (Utilize a Python list to hold the number of staffed beds for each hospital.)
#
# </b>
#
# </div>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
bed_median_LA = np.median(staffed_beds_LA) # SOLUTION
bed_median_LA
# Out:
# 316.5

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(bed_median_LA) ==  np.float64
# Out:
# True

# %%
bed_median_LA - 316.5 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# <div class="alert alert-info">
#     <b>16. Compare and contrast the median number of staffed beds for San Francisco and Los Angeles Hospitals.
# </b>
#
# </div>

# %% [markdown]
# *Type answer here*
