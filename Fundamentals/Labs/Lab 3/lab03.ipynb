# %% [raw]
# # ASSIGNMENT CONFIG
# init_cell: true
# export_cell: true
# export_cell:
#     pdf: false
#     force_save: false
# solutions_pdf: true
# template_pdf: false
# generate:
#     points_possible: 18
#     show_stdout: true
#     zips: false

# %%
# Don't change this cell; just run it. 

import numpy as np
from datascience import *
#import d8error

# %% [markdown]
# # Lab 3: Objects, Lists, Built-In Functions, Libraries
#
# Welcome to Lab 3 of Introduction to Computational Thinking with Data!
#
# Collaborating on labs is more than okay -- it's encouraged! You should rarely remain stuck for more than a few minutes on questions in labs, so ask an instructor or classmate for help. (Explaining things is beneficial, too -- the best way to solidify your knowledge of a subject is to explain it.) Please don't just share answers, though.
#
# In this lab, we will be focusing on:
#
# <ul>
#     <li> Debuggings code</li>
#     <li> Continuing Objects and lists</li>
#     <li> Getting familiar with Built-In Functions and Libraries</li>
#     <li> Numpy Import Introduction</li>
# </ul>
#
# ---

# %% [markdown]
# ## Part 1: Comments and Debugging
#
# <b>Debugging</b> in Python or any programming language involves identifying and fixing errors in your code, which can include syntax, semantic, and runtime issues.
#
# <b> Comments </b> are hints that we add to our code to make it easier to understand. Python comments start with a <b>#</b>. Comments are completely ignored and not executed by code editors or interpreters.

# %% [markdown]
# ### Debugging Examples
#
# <div class="alert alert-info">
#     <b>1. Fix the following Code bugs. Add a comment above the corrected code identifying the solution.</b>
# </div>

# %%
print "Hello"
# Out:
#   Cell In[2], line 1
#     print "Hello"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# Type answer here

# %%
print "Hello )
# Out:
#   Cell In[3], line 1
#     print "Hello )
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# Type answer here

# %%
#expected outcome is 5
print("2" + "3")
# Out:
# 23

# %%
# Type answer here

# %%
#expected outcome is 2 + 3 = 5
print("2 + 3, 2 + 3)
# Out:
#   Cell In[6], line 2
#     print("2 + 3, 2 + 3)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# Type answer here

# %%
#expected output is 1
-x = 1
print (x)
# Out:
#   Cell In[7], line 2
#     -x = 1
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# Type answer here

# %%
#expected output 100
a = 10
print("a x 10", A)

# %%
# Type answer here

# %%
a = [1,2,3
print a
# Out:
#   Cell In[8], line 1
#     a = [1,2,3
#         ^
# SyntaxError: '[' was never closed

# %%
# Type answer here

# %%
sample = [25,98,632,,]
print(sampe)
# Out:
#   Cell In[10], line 1
#     sample = [25,98,632,,]
#                         ^
# SyntaxError: invalid syntax

# %%
# Type answer here

# %%
sample = [-987, ”34 ” , 100, 900, 200, 50,987,1500]
print(sum( sample)
# Out:
#   Cell In[12], line 1
#     sample = [-987, ”34 ” , 100, 900, 200, 50,987,1500]
#                     ^
# SyntaxError: invalid character '”' (U+201D)

# %%
# Type answer here

# %% [markdown]
# ---

# %% [markdown]
# ## Part 2: Python Library and Numpy Introduction
#
# Before we get started here, make sure Numpy is installed on your machine or instance of Jupyterhub as this library is necessary for the following section.
#
# <b>External libraries</b> in Python are Classes are collections of pre-written code that can used to solve programming tasks.
#
# <b> import </b> in Python allows the programmer to access code defined in one module from another module.
#
# In the previous lab, we used the built-in function sum() to add values in a Python list. In the exercise below, we will use the Numpy .sum() to the values in the list.
#
# ---
# #### Sum a List
# Example:
# ```python
# import numpy as np
# list1 = [2,4,6,8]
# x = np.sum(list1)
# ```

# %% [raw]
# # BEGIN QUESTION
# name: ex1
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>1. Write the code below: [ Find the sum using the Numpy .sum() ]</b>
# </div>
#
# ```python
# sample = [25, 34, 100, 900, 200,50]
# print(sample)
# ```

# %% [raw]
# # BEGIN SOLUTION

# %%
...
mean = (25 + 34 + 100 + 900 + 200 + 50)/ 6 # SOLUTION
mean
# Out:
# 218.16666666666666

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(mean) == np.float64
# Out:
# True

# %%
mean - (25 + 34 + 100 + 900 + 200 + 50)/ 6 < 0.0001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ---
# ### Mean Average Review
#
# We use the Numpy .mean() to find the mean average rather than calculating it number by number.
#
# #### Example:

# %%
import numpy as np 
sample = [25,34, 100, 900, 200, 50]
mean_avg = np.mean(sample)
print(mean_avg)
# Out:
# 218.166666667

# %% [markdown]
# <div class="alert alert-warning">
# <b>Make sure variable names follow programming conventions and avoid key words in python.</b>
# </div>

# %% [raw]
# # BEGIN QUESTION
# name: ex2
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b> 2. Write the code below: [ Output the Mean of the list below using the Numpy .mean() ]</b>
# </div>
#
# ```python
# sample = [25,34, 100, 900, 200, 50,987,1500]
# print(sample)
# ```

# %% [raw]
# # BEGIN SOLUTION

# %%
...
mean = (25 + 34 + 100 + 900 + 200 + 50 + 987 + 1500) / 8 # SOLUTION
mean
# Out:
# 474.5

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(mean) == np.float64
# Out:
# True

# %%
mean - (25 + 34 + 100 + 900 + 200 + 50 + 987 + 1500) / 8 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: ex3
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>3.  Write the code below: [ Output the Mean of the list below using the Numpy .mean() ]</b>
# </div>
#
# ```python
# sample = [-987, 34 , 100, 900, 200, 50,987,1500]
# print(sample)
# ```

# %% [raw]
# # BEGIN SOLUTION

# %%
...
mean = (-987 + 34 + 100 + 900 + 200 + 50 + 987 + 1500) / 8 # SOLUTION
mean
# Out:
# 348.0

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(mean) == np.float64
# Out:
# True

# %%
mean - (-987 + 34 + 100 + 900 + 200 + 50 + 987 + 1500) / 8 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ---
#
# ### Frozen Desserts and Sugar Bomb Mean Averages
#
# Now that we have reviewed mean averages and how to compute them using Numpy, lets take a look at previous data sets and find their mean averages!

# %% [raw]
# # BEGIN QUESTION
# name: ex4
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>4. Output the Mean for the Grams of Sugar Column in the Frozen Desserts Data Set. [ Use Numpy .mean() ]
#
# <i> Make sure variable names follow programming conventions and avoid key words in python.</i> </b>
# </div>
#
# <img src="https://github.com/IndarF/data_module_drafts/blob/main/Fundamentals/Labs/Lab%203/frozen_desserts.jpg?raw=true" width="800"/>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
dessert_mean = np.mean(frozen_dessert) # SOLUTION
dessert_mean
# Out:
# 19.5

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(dessert_mean) == np.float64
# Out:
# True

# %%
dessert_mean - 19.5 < 0.0001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: ex5
# points: 2

# %% [markdown]
# <div class="alert alert-info">
# <b>5. Output the Mean for the Grams of Sugar Column in the Sugar Bomb Data Set. [ Use Numpy .mean() ]
#
# <i> Make sure variable names follow programming conventions and avoid key words in python.</i> </b>
# </div>
#
# <img src="https://github.com/IndarF/data_module_drafts/blob/main/Fundamentals/Labs/Lab%203/sugar_bomb.png?raw=true" width="800"/>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
sbomb_mean = np.mean(sugar_bomb) # SOLUTION
sbomb_mean
# Out:
# 22.774193548387096

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(sbomb_mean) == np.float64
# Out:
# True

# %%
sbomb_mean - np.mean(sugar_bomb) < 0.0001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# <div class="alert alert-info">
#     <b>6. Did you receive the same answer as Lab 1 and Lab 2?</b>
# </div>

# %% [markdown]
# *Type answer here*

# %% [markdown]
# <div class="alert alert-info">
#     <b>7. Does the mean average differ for the Frozen Dessert and Sugar Bomb Data Sets?</b>
# </div>

# %% [markdown]
# *Type answer here*

# %% [markdown]
# ---
# ### Median Average Review

# %% [markdown]
# A <b>Median</b> is the middle value in an ordered or sorted list. With Numpy, we can use their `Numpy.median()` method to output the median average. You do not need to sort the list first!

# %% [markdown]
# #### Example:

# %% [markdown]
# ```python
# import numpy as np
# sample = [25,34, 100, 900, 200, 50]
# median_avg = np.median(sample)
# print(mean_avg)
# ```

# %% [markdown]
# A Data Set can have:
# <ul>
#     <li> <b>Odd number</b> of entries: median is the middle data entry
#         <ul>
#             <li> .median() will output the <b>middle element</b> of the list.</li>
#         </ul>
#     </li>
#     <li> <b>Even number</b> of entries: median is the mean of the two middle data entries
#         <ul>
#             <li> .median() will output the <b>mean average</b> of the (2) middle elements of the list.</li>
#         </ul>
#     </li>
# </ul>

# %% [raw]
# # BEGIN QUESTION
# name: ex8
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>8. Write the code below: [ Use Numpy .median() to output the median average. ]
#     </b>
# </div>

# %% [markdown]
# ```python
# sample = [25,34, 1000, 200, 50]
# ```

# %% [raw]
# # BEGIN SOLUTION

# %%
...
median = 50.0 # SOLUTION
median
# Out:
# 50.0

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
median - 50 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: ex9
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>9. Write the code below:
#     [ Use Numpy .median() to output the median average. ] </b>
# </div>

# %% [markdown]
# ```python
# sample = [25,34, 1000, 200, 50, 13]
# ```

# %% [raw]
# # BEGIN SOLUTION

# %%
...
median = 42.0 # SOLUTION
median
# Out:
# 42.0

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
median - 42.0 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ---
# ### Frozen Desserts and Sugar Bomb Medians
#
# Now that we have reviewed computing medians for odd and even numbered lists, lets find the medians of the Sugar Bomb and Frozen dessert data sets.

# %% [raw]
# # BEGIN QUESTION
# name: ex10
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>10. Output the Median for the Grams of Sugar Column in the Sugar Bomb Data Set. [ Use Numpy .median() ]
#
# Make sure variable names follow programming conventions and avoid key words in python.
#  </b>
# </div>
#
# <img src="https://github.com/IndarF/data_module_drafts/blob/main/Fundamentals/Labs/Lab%203/sugar_bomb.png?raw=true" width="800"/>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
sbomb_median = np.median(sugar_bomb) # SOLUTION
sbomb_median
# Out:
# 20.0

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
sbomb_median - 20.0 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: ex11
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>11. Output the Median for the Grams of Sugar Column in the Frozen Desserts Data Set. [ Use Numpy .median() ]
#
# Make sure variable names follow programming conventions and avoid key words in python.
#  </b>
# </div>
#
# <img src="https://github.com/IndarF/data_module_drafts/blob/main/Fundamentals/Labs/Lab%203/frozen_desserts.jpg?raw=true" width="800"/>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
dessert_median = np.median(frozen_dessert) # SOLUTION
dessert_median
# Out:
# 20.0

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
dessert_median - 20.0 < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# <div class="alert alert-info">
#     <b>12. Did you receive the same answer as Lab 1 and Lab 2?</b>
# </div>

# %% [markdown]
# *Type answer here*

# %% [markdown]
# <div class="alert alert-info">
#     <b>13. Does the median average differ for the Frozen Dessert and Sugar Bomb Data Sets?</b>
# </div>

# %% [markdown]
# *Type answer here*

# %% [markdown]
# ---
# ### Standard Deviation Review

# %% [markdown]
# <b>Standard Deviation</b> is the most common measure of variation or spread. A number that measuires how far data are from the mean.
#
# Use `Numpy.std()` to output the standard deviation.
#
# #### Example:
# ```python
# import numpy as np
# sample = [25,34, 100, 900, 200, 50]
# standard = np.std(sample)
# print(standard)
# ```

# %% [raw]
# # BEGIN QUESTION
# name: ex14
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>14. Write the code below: [ Use Numpy.std() to output the standard deviation. ]</b>
# </div>
#
# ```python
# sample = [25,34, 1000, 200, 50]
# ```

# %% [raw]
# # BEGIN SOLUTION

# %%
...
sample_std = np.std([25, 34, 1000, 200, 50]) # SOLUTION
sample_std
# Out:
# 374.58905483209202

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(sample_std) == np.float64
# Out:
# True

# %%
sample_std - np.std([25, 34, 1000, 200, 50]) < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: ex15
# points: 2

# %% [markdown]
# <div class="alert alert-info">
#     <b>15. Output the Standard Deviation for the Grams of Sugar Column in the Sugar Bomb Data Set. [ Use Numpy.std() ]
#
# Make sure variable names follow programming conventions and avoid key words in python.
#  </b>
# </div>
#
# <img src="https://github.com/IndarF/data_module_drafts/blob/main/Fundamentals/Labs/Lab%203/sugar_bomb.png?raw=true" width="800"/>

# %% [raw]
# # BEGIN SOLUTION

# %%
...
sbomb_std = np.std(sugar_bomb) # SOLUTION
sbomb_std
# Out:
# 14.783839645782702

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
type(sbomb_std) == np.float64
# Out:
# True

# %%
sbomb_std - np.std(sugar_bomb) < 0.00001
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# <div class="alert alert-info">
#     <b>16. Suppose you randomly pick a frozen dessert from the dataset. Based on the average and standard deviation, what range of sugar content would you expect most desserts to fall into?
# </b>
# </div>

# %% [markdown]
# *Type answer here*

# %% [markdown]
# <div class="alert alert-info">
#     <b>17. The American Heart Association recommends children aged 2-18 limit their daily intake of added sugar to less than 25 grams. Based on your answer to question 15, do these desserts typically fall within the recommendation? Explain your reasoning.
#
# </b>
# </div>

# %% [markdown]
# *Type answer here*
